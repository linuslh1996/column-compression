# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
simdcai = pd.read_csv("simdcai_out.csv", sep="|")
simdcai
# Out:
#       Unnamed: 0  table_name  chunk_id  column_id      column_name  \
# 0            NaN      nation         0          0      n_nationkey
# 1            NaN      nation         0          1           n_name
# 2            NaN      nation         0          2      n_regionkey
# 3            NaN      nation         0          3        n_comment
# 4            NaN        part         0          0        p_partkey
# ...          ...         ...       ...        ...              ...
# 1813         NaN    customer         2          6     c_mktsegment
# 1814         NaN    customer         2          7        c_comment
# 1815         NaN      region         0          0      r_regionkey
# 1816         NaN      region         0          1           r_name
# 1817         NaN      region         0          2        r_comment
#
#       column_data_type  distinct_value_count  encoding_type  \
# 0                  int                    25        SIMDCAI
# 1               string                    25     Dictionary
# 2                  int                     5        SIMDCAI
# 3               string                    25     Dictionary
# 4                  int                 65535        SIMDCAI
# ...                ...                   ...            ...
# 1813            string                     5     Dictionary
# 1814            string                 18930     Dictionary
# 1815               int                     5        SIMDCAI
# 1816            string                     5     Dictionary
# 1817            string                     5     Dictionary
#
#       vector_compression_type  size_in_bytes  point_accesses  \
# 0                        NULL            185           11820
# 1       FixedSize1ByteAligned           1153               0
# 2                        NULL            169               0
# 3       FixedSize1ByteAligned           3035               0
# 4                        NULL         131225               0
# ...                       ...            ...             ...
# 1813    FixedSize1ByteAligned          19258               0
# 1814    FixedSize2ByteAligned        2187310               0
# 1815                     NULL            169           19160
# 1816    FixedSize1ByteAligned            333               0
# 1817    FixedSize1ByteAligned            668               0
#
#       sequential_accesses  monotonic_accesses  random_accesses  \
# 0                   84175              141915             7520
# 1                  342525                   0         92019059
# 2                  479075                   0                0
# 3                      25                   0                0
# 4               165541410            21812299         10498144
# ...                   ...                 ...              ...
# 1813             12607380                   0                0
# 1814                18930                   0          1868908
# 1815                   15                   0                0
# 1816                95805                   0                0
# 1817                    5                   0                0
#
#       dictionary_accesses  Unnamed: 15
# 0                       0          NaN
# 1                29206278          NaN
# 2                       0          NaN
# 3                      25          NaN
# 4                       0          NaN
# ...                   ...          ...
# 1813                22255          NaN
# 1814                18930          NaN
# 1815                    0          NaN
# 1816                95805          NaN
# 1817                    5          NaN
#
# [1818 rows x 16 columns]

# %%
dictionary = pd.read_csv("dictionary_out.csv", sep="|")
dictionary
# Out:
#       Unnamed: 0  table_name  chunk_id  column_id      column_name  \
# 0            NaN      nation         0          0      n_nationkey
# 1            NaN      nation         0          1           n_name
# 2            NaN      nation         0          2      n_regionkey
# 3            NaN      nation         0          3        n_comment
# 4            NaN        part         0          0        p_partkey
# ...          ...         ...       ...        ...              ...
# 1813         NaN    customer         2          6     c_mktsegment
# 1814         NaN    customer         2          7        c_comment
# 1815         NaN      region         0          0      r_regionkey
# 1816         NaN      region         0          1           r_name
# 1817         NaN      region         0          2        r_comment
#
#       column_data_type  distinct_value_count  encoding_type  \
# 0                  int                    25     Dictionary
# 1               string                    25     Dictionary
# 2                  int                     5     Dictionary
# 3               string                    25     Dictionary
# 4                  int                 65535     Dictionary
# ...                ...                   ...            ...
# 1813            string                     5     Dictionary
# 1814            string                 18930     Dictionary
# 1815               int                     5     Dictionary
# 1816            string                     5     Dictionary
# 1817            string                     5     Dictionary
#
#       vector_compression_type  size_in_bytes  point_accesses  \
# 0       FixedSize1ByteAligned            221           17183
# 1       FixedSize1ByteAligned           1153               0
# 2       FixedSize1ByteAligned            141               0
# 3       FixedSize1ByteAligned           3035               0
# 4       FixedSize2ByteAligned         393306               0
# ...                       ...            ...             ...
# 1813    FixedSize1ByteAligned          19258               0
# 1814    FixedSize2ByteAligned        2187310               0
# 1815    FixedSize1ByteAligned            121           29285
# 1816    FixedSize1ByteAligned            333               0
# 1817    FixedSize1ByteAligned            668               0
#
#       sequential_accesses  monotonic_accesses  random_accesses  \
# 0                   87625              218360             6608
# 1                  470900                   0         93066942
# 2                  732150                   0                0
# 3                      25                   0                0
# 4               164951595            25635312          9958529
# ...                   ...                 ...              ...
# 1813             11774460                   0                0
# 1814                18930                   0          1989316
# 1815                    5                   0                0
# 1816               146430                   0                0
# 1817                    5                   0                0
#
#       dictionary_accesses  Unnamed: 15
# 0                  323168          NaN
# 1                32240604          NaN
# 2                  732150          NaN
# 3                      25          NaN
# 4               190586907          NaN
# ...                   ...          ...
# 1813                22035          NaN
# 1814                18930          NaN
# 1815                29290          NaN
# 1816               146430          NaN
# 1817                    5          NaN
#
# [1818 rows x 16 columns]

# %%
cols_with_simdcai_flags = simdcai["encoding_type"].str.match(".*SIMDCAI.*")
cols_with_simdcai = simdcai[cols_with_simdcai_flags]
cols_with_simdcai
# Out:
#       Unnamed: 0  table_name  chunk_id  column_id      column_name  \
# 0            NaN      nation         0          0      n_nationkey
# 2            NaN      nation         0          2      n_regionkey
# 4            NaN        part         0          0        p_partkey
# 9            NaN        part         0          5           p_size
# 13           NaN        part         1          0        p_partkey
# ...          ...         ...       ...        ...              ...
# 1799         NaN    customer         1          0        c_custkey
# 1802         NaN    customer         1          3      c_nationkey
# 1807         NaN    customer         2          0        c_custkey
# 1810         NaN    customer         2          3      c_nationkey
# 1815         NaN      region         0          0      r_regionkey
#
#       column_data_type  distinct_value_count  encoding_type  \
# 0                  int                    25        SIMDCAI
# 2                  int                     5        SIMDCAI
# 4                  int                 65535        SIMDCAI
# 9                  int                    50        SIMDCAI
# 13                 int                 65535        SIMDCAI
# ...                ...                   ...            ...
# 1799               int                 65535        SIMDCAI
# 1802               int                    25        SIMDCAI
# 1807               int                 18930        SIMDCAI
# 1810               int                    25        SIMDCAI
# 1815               int                     5        SIMDCAI
#
#       vector_compression_type  size_in_bytes  point_accesses  \
# 0                        NULL            185           11820
# 2                        NULL            169               0
# 4                        NULL         131225               0
# 9                        NULL          49305            1260
# 13                       NULL         131225               0
# ...                       ...            ...             ...
# 1799                     NULL         131225               0
# 1802                     NULL          41113               0
# 1807                     NULL          35657               0
# 1810                     NULL          11993               0
# 1815                     NULL            169           19160
#
#       sequential_accesses  monotonic_accesses  random_accesses  \
# 0                   84175              141915             7520
# 2                  479075                   0                0
# 4               165541410            21812299         10498144
# 9               593157285            72485844          5924016
# 13              165541410            21801590         10554349
# ...                   ...                 ...              ...
# 1799             50199810            40087099        103256739
# 1802            145815375             4928035         13969828
# 1807             14500380            11568333         29789818
# 1810             42119250             1427498          4038984
# 1815                   15                   0                0
#
#       dictionary_accesses  Unnamed: 15
# 0                       0          NaN
# 2                       0          NaN
# 4                       0          NaN
# 9                       0          NaN
# 13                      0          NaN
# ...                   ...          ...
# 1799                    0          NaN
# 1802                    0          NaN
# 1807                    0          NaN
# 1810                    0          NaN
# 1815                    0          NaN
#
# [495 rows x 16 columns]

# %%
cols_with_simdcai_dict_encoded = dictionary[cols_with_simdcai_flags]
cols_with_simdcai_dict_encoded
# Out:
#       Unnamed: 0  table_name  chunk_id  column_id      column_name  \
# 0            NaN      nation         0          0      n_nationkey
# 2            NaN      nation         0          2      n_regionkey
# 4            NaN        part         0          0        p_partkey
# 9            NaN        part         0          5           p_size
# 13           NaN        part         1          0        p_partkey
# ...          ...         ...       ...        ...              ...
# 1799         NaN    customer         1          0        c_custkey
# 1802         NaN    customer         1          3      c_nationkey
# 1807         NaN    customer         2          0        c_custkey
# 1810         NaN    customer         2          3      c_nationkey
# 1815         NaN      region         0          0      r_regionkey
#
#       column_data_type  distinct_value_count  encoding_type  \
# 0                  int                    25     Dictionary
# 2                  int                     5     Dictionary
# 4                  int                 65535     Dictionary
# 9                  int                    50     Dictionary
# 13                 int                 65535     Dictionary
# ...                ...                   ...            ...
# 1799               int                 65535     Dictionary
# 1802               int                    25     Dictionary
# 1807               int                 18930     Dictionary
# 1810               int                    25     Dictionary
# 1815               int                     5     Dictionary
#
#       vector_compression_type  size_in_bytes  point_accesses  \
# 0       FixedSize1ByteAligned            221           17183
# 2       FixedSize1ByteAligned            141               0
# 4       FixedSize2ByteAligned         393306               0
# 9       FixedSize1ByteAligned          65831            1017
# 13      FixedSize2ByteAligned         393306               0
# ...                       ...            ...             ...
# 1799    FixedSize2ByteAligned         393306               0
# 1802    FixedSize1ByteAligned          65731               0
# 1807    FixedSize2ByteAligned         113676               0
# 1810    FixedSize1ByteAligned          19126               0
# 1815    FixedSize1ByteAligned            121           29285
#
#       sequential_accesses  monotonic_accesses  random_accesses  \
# 0                   87625              218360             6608
# 2                  732150                   0                0
# 4               164951595            25635312          9958529
# 9               927582390            77724260          6364410
# 13              164951595            25628743          9962211
# ...                   ...                 ...              ...
# 1799             58260615            35939423        127714181
# 1802            130414650             4331529         18638291
# 1807             16828770            10360710         36858397
# 1810             37670700             1250161          5386165
# 1815                    5                   0                0
#
#       dictionary_accesses  Unnamed: 15
# 0                  323168          NaN
# 2                  732150          NaN
# 4               190586907          NaN
# 9                76796281          NaN
# 13              190580338          NaN
# ...                   ...          ...
# 1799             94200038          NaN
# 1802            134746179          NaN
# 1807             27189480          NaN
# 1810             38920861          NaN
# 1815                29290          NaN
#
# [495 rows x 16 columns]

# %%
size1 = cols_with_simdcai["size_in_bytes"].sum()
size2 = cols_with_simdcai_dict_encoded["size_in_bytes"].sum()
print(size1)
print(size2)
size1/size2
# Out:
# 56482311
# 109498396
# 0.5158277478329454

# %%
int_cols = dictionary[dictionary["column_data_type"].str.match(".*int.*")]
int_cols["size_in_bytes"].sum() / dictionary["size_in_bytes"].sum()
# Out:
# 0.11353100856895045

# %%
dictionary["column_data_type"].unique()
# Out:
# array(['             int', '          string', '           float'],
#       dtype=object)

# %%
simdcai["size_in_bytes"].sum() / dictionary["size_in_bytes"].sum()
# Out:
# 0.9450314358903741

# %%
import pandas as pd
import matplotlib.pyplot as plt

dictionary = pd.read_csv("sizes_none.txt", sep="|")
dict_size = dictionary["size_in_bytes"].sum()
print("dictionary size", dict_size)

for name in [("fsba", "FixedSize"), ("SIMDBP", "SimdBp128"), ("turbopfor", "TurboPForBitpacking")]:
    runtimes = pd.read_csv("sizes_" + name[0] + ".txt", sep="|")
    s = runtimes["size_in_bytes"].sum()

    #print(runtimes)


    #cols_with_name_flags = simdcai["encoding_type"].str.match(".*" + name + ".*")
    cols_with_name_flags = runtimes["vector_compression_type"].str.match(".*" + name[1] + ".*")
    cols_with_name = runtimes[cols_with_name_flags]    

    cols_with_name_dict_encoded = dictionary[cols_with_name_flags]

    size1 = cols_with_name["size_in_bytes"].sum()
    size2 = cols_with_name_dict_encoded["size_in_bytes"].sum()


    print(name, "size:", s)
    print("\ttotal percentage:", s / dict_size, "\n\tencoded col percentage:", size2 / dict_size, "\n\tencoded col compression:", size1 / size2)
# Out:
# dictionary size 964591082
# ('fsba', 'FixedSize') size: 964591082
# 	total percentage: 1.0
# 	encoded col percentage: 1.0
# 	encoded col compression: 1.0
# ('SIMDBP', 'SimdBp128') size: 920498972
# 	total percentage: 0.9542893244372749
# 	encoded col percentage: 1.0
# 	encoded col compression: 0.9542893244372749
# ('turbopfor', 'TurboPForBitpacking') size: 924574516
# 	total percentage: 0.9585144765002088
# 	encoded col percentage: 1.0
# 	encoded col compression: 0.9585144765002088

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(30,15)})


d = dictionary[["    column_name",'table_name','size_in_bytes']]
d['id'] = d["    column_name"].map(str) + d.table_name
#print(d)
#print(d.table_name)

d = d.groupby("id")["size_in_bytes"].sum()

#print(d["size_in_bytes"].sum())
d.plot.barh()
# Out:
# <AxesSubplot:ylabel='id'>

# %%
# Out:
# 0           n_nationkey
# 1                n_name
# 2           n_regionkey
# 3             n_comment
# 4             p_partkey
#              ...
# 1813       c_mktsegment
# 1814          c_comment
# 1815        r_regionkey
# 1816             r_name
# 1817          r_comment
# Name:     column_name, Length: 1818, dtype: object

# %%
# Out:
#       Unnamed: 0  table_name  chunk_id  column_id      column_name  \
# 1585         NaN      orders         0          8        o_comment
# 1594         NaN      orders         1          8        o_comment
# 1603         NaN      orders         2          8        o_comment
# 1612         NaN      orders         3          8        o_comment
# 1621         NaN      orders         4          8        o_comment
# 1630         NaN      orders         5          8        o_comment
# 1639         NaN      orders         6          8        o_comment
# 1648         NaN      orders         7          8        o_comment
# 1657         NaN      orders         8          8        o_comment
# 1666         NaN      orders         9          8        o_comment
# 1675         NaN      orders        10          8        o_comment
# 1684         NaN      orders        11          8        o_comment
# 1693         NaN      orders        12          8        o_comment
# 1702         NaN      orders        13          8        o_comment
# 1711         NaN      orders        14          8        o_comment
# 1720         NaN      orders        15          8        o_comment
# 1729         NaN      orders        16          8        o_comment
# 1738         NaN      orders        17          8        o_comment
# 1747         NaN      orders        18          8        o_comment
# 1756         NaN      orders        19          8        o_comment
# 1765         NaN      orders        20          8        o_comment
# 1774         NaN      orders        21          8        o_comment
# 1783         NaN      orders        22          8        o_comment
#
#       column_data_type  distinct_value_count  encoding_type  \
# 1585            string                 65490     Dictionary
# 1594            string                 65490     Dictionary
# 1603            string                 65495     Dictionary
# 1612            string                 65485     Dictionary
# 1621            string                 65481     Dictionary
# 1630            string                 65498     Dictionary
# 1639            string                 65492     Dictionary
# 1648            string                 65487     Dictionary
# 1657            string                 65498     Dictionary
# 1666            string                 65486     Dictionary
# 1675            string                 65489     Dictionary
# 1684            string                 65491     Dictionary
# 1693            string                 65478     Dictionary
# 1702            string                 65490     Dictionary
# 1711            string                 65481     Dictionary
# 1720            string                 65486     Dictionary
# 1729            string                 65482     Dictionary
# 1738            string                 65494     Dictionary
# 1747            string                 65489     Dictionary
# 1756            string                 65481     Dictionary
# 1765            string                 65491     Dictionary
# 1774            string                 65484     Dictionary
# 1783            string                 58185     Dictionary
#
#       vector_compression_type  size_in_bytes  point_accesses  \
# 1585    FixedSize2ByteAligned        6005731               0
# 1594    FixedSize2ByteAligned        5989719               0
# 1603    FixedSize2ByteAligned        5997404               0
# 1612    FixedSize2ByteAligned        5993746               0
# 1621    FixedSize2ByteAligned        5996456               0
# 1630    FixedSize2ByteAligned        5998846               0
# 1639    FixedSize2ByteAligned        5998921               0
# 1648    FixedSize2ByteAligned        5994723               0
# 1657    FixedSize2ByteAligned        5994417               0
# 1666    FixedSize2ByteAligned        5999613               0
# 1675    FixedSize2ByteAligned        5992790               0
# 1684    FixedSize2ByteAligned        5994411               0
# 1693    FixedSize2ByteAligned        5988391               0
# 1702    FixedSize2ByteAligned        5997207               0
# 1711    FixedSize2ByteAligned        5988121               0
# 1720    FixedSize2ByteAligned        5987207               0
# 1729    FixedSize2ByteAligned        5993156               0
# 1738    FixedSize2ByteAligned        5993833               0
# 1747    FixedSize2ByteAligned        5989176               0
# 1756    FixedSize2ByteAligned        5989165               0
# 1765    FixedSize2ByteAligned        5998448               0
# 1774    FixedSize2ByteAligned        5997166               0
# 1783    FixedSize2ByteAligned        5323909               0
#
#       sequential_accesses  monotonic_accesses  random_accesses  \
# 1585              7339920                   0                0
# 1594              7339920                   0                0
# 1603              7339920                   0                0
# 1612              7339920                   0                0
# 1621              7339920                   0                0
# 1630              7339920                   0                0
# 1639              7339920                   0                0
# 1648              7339920                   0                0
# 1657              7339920                   0                0
# 1666              7339920                   0                0
# 1675              7339920                   0                0
# 1684              7339920                   0                0
# 1693              7339920                   0                0
# 1702              7339920                   0                0
# 1711              7339920                   0                0
# 1720              7339920                   0                0
# 1729              7339920                   0                0
# 1738              7339920                   0                0
# 1747              7339920                   0                0
# 1756              7339920                   0                0
# 1765              7339920                   0                0
# 1774              7339920                   0                0
# 1783              6521760                   0                0
#
#       dictionary_accesses  Unnamed: 15
# 1585                65535          NaN
# 1594                65535          NaN
# 1603                65535          NaN
# 1612                65535          NaN
# 1621                65535          NaN
# 1630                65535          NaN
# 1639                65535          NaN
# 1648                65535          NaN
# 1657                65535          NaN
# 1666                65535          NaN
# 1675                65535          NaN
# 1684                65535          NaN
# 1693                65535          NaN
# 1702                65535          NaN
# 1711                65535          NaN
# 1720                65535          NaN
# 1729                65535          NaN
# 1738                65535          NaN
# 1747                65535          NaN
# 1756                65535          NaN
# 1765                65535          NaN
# 1774                65535          NaN
# 1783                58230          NaN
